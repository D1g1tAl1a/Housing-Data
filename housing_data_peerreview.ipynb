# %%
import pandas as pd
import numpy as np
import scipy.linalg as alg
import seaborn as sbn
import matplotlib_inline as pltline
import matplotlib.pyplot as plt
house = pd.read_csv("sample dataset  housing_data .csv")
size = house.iloc[:, 0]
price = house.iloc[:, 1]
sizemean= np.average(size)
pricemean = np.average(price)
sbn.scatterplot(house, x=size, y=price)
plt.show()
sbn.histplot(house, x=size, y=price, binwidth=200)
plt.show()
